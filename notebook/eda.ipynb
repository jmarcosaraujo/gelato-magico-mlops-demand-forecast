# %% [markdown]
# # 📌 Célula 1 – Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %% [markdown]
# # 📌 Célula 2 – Carregar dados

# %%
df = pd.read_csv("../data/vendas_sorvete.csv")
df.head()

# %% [markdown]
# # 📌 Célula 3 – Estatísticas

# %%
df.describe()

# %% [markdown]
# # 📌 Célula 4 – Correlação

# %%
df.corr()

# %% [markdown]
# # 📌 Célula 5 – Gráfico

# %%
plt.figure()
plt.scatter(df["temperatura"], df["vendas"])
plt.xlabel("Temperatura")
plt.ylabel("Vendas")
plt.title("Relação entre Temperatura e Vendas")
plt.show()

# %% [markdown]
# # 📌 Insight Final (Markdown)

# %% [markdown]
# Observa-se uma forte correlação positiva entre temperatura e vendas.
# O comportamento indica viabilidade para modelos de regressão.
